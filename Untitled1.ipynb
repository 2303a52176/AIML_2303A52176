# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a52176/AIML_2303A52176/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lists and Arrays

# %%
import numpy as np
list1 = [5,6,7]
array1=np.array(list1)
array1
# Out:
# array([5, 6, 7])

# %% [markdown]
# Identify their type using type()

# %%
type(list1)
# Out:
# list

# %%
type(array1)
# Out:
# numpy.ndarray

# %% [markdown]
# SECOND ARRAY

# %%
import numpy as np
list2=[1,2,3]
array2=np.array(list2)
array2
# Out:
# array([1, 2, 3])

# %% [markdown]
# Perform mathematical operations on these datasets created - multiplication, division,
# powerof

# %%
print("multiplication of array1 & list1" ,array1*list1)
print("division of array1 on list1" ,array1/list1)
print("powerof of array1 on list1 ",array1**list1)
# Out:
# multiplication of array1 & list1 [25 36 49]
# division of array1 on list1 [1. 1. 1.]
# powerof of array1 on list1  [  3125  46656 823543]

# %% [markdown]
#  Implement np.sin(), log(), log2(), np.exp())

# %%
#sin
print("sin:",np.sin(array1))
#logorithm
print("natureal logrthim",np.log(array1))
print("base 2 logarithm",np.log2(array1))
print("base 10 logarithm",np.log10(array1))
#exponential
print("exponential",np.exp(array1))
# Out:
# sin: [-0.95892427 -0.2794155   0.6569866 ]
# natureal logrthim [1.60943791 1.79175947 1.94591015]
# base 2 logarithm [2.32192809 2.5849625  2.80735492]
# base 10 logarithm [0.69897    0.77815125 0.84509804]
# exponential [ 148.4131591   403.42879349 1096.63315843]

# %% [markdown]
# Combine text with Numpy fuction to generate a textual output - ”Addition of Two:
# array1 +array 2

# %%
print("addation of two numpy arrays {array1} anbd {array2} together",array1+array2)
# Out:
# addation of two numpy arrays {array1} anbd {array2} together [ 6  8 10]

# %%
print(f"Addition of two numpy arrays {array1} and {array2} together: {array1 + array2}")
# Out:
# Addition of two numpy arrays [5 6 7] and [1 2 3] together: [ 6  8 10]

# %% [markdown]
# # Part 2 – Visualization of Data using matplotlib, pyplots Packages

# %%
people = ['kiran', 'arun', 'vijay', 'varun', 'amit', 'neha', 'sita', 'rajesh', 'manoj', 'priya', 'kavi', 'anil', 'sonia', 'deepak', 'nisha']
age = [25, 30, 35, 40, 45, 28, 33, 38, 42, 29, 31, 37, 43, 27, 32]
height = [145, 151, 165, 173, 160, 155, 170, 175, 168, 162, 159, 172, 178, 157, 163]
weight = [45, 55, 65, 75, 70, 60, 80, 85, 72, 68, 64, 77, 82, 58, 66]

# %% [markdown]
# # ***Generate Scatterplot***
# Let's suppose we collected age (in years), height (in cm), and weight (in kilograms) information from few patients visitng a clinic.

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(weight,height)
plt.title("relationship between Weight and Height of Patients")
plt.ylabel("Height in Meters")
plt.xlabel("Weight in Kgs")
plt.show()

# %% [markdown]
# Generate Bar Plot

# %%
plt.figure(figsize=(12,4))
plt.title("People's weight in kgs",fontsize=16,fontstyle="italic")
#main plot function "bar"
plt.bar(x=people,height=weight,width=0.6,color='orange',edgecolor='k',alpha=0.7)

plt.xlabel("People",fontsize=15)
plt.xticks(fontsize=14,rotation=10)
plt.yticks(fontsize=14)
plt.ylabel("Weight ( in kgs)",fontsize=15)
plt.show()

# %% [markdown]
# ### Generate Histogram

# %%
import numpy as np
plt.figure(figsize=(7,5))
# main plot function 'hist'
plt.hist(weight,color='yellow',edgecolor='k',alpha=0.8,bins=5)

plt.title("Histogram of patient weight",fontsize=18)
plt.xlabel("Weight in kgs",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# Part-03: Access Data from various sources and formats

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_table("52176txt.txt")

# %%
df1
# Out:
#   vhsfdbvjdavbdakvcndakvndakvcndkvcn;kadnclad;cldncl;dcnl;dndvnkdcndkvc
# 0  dkndkdanldvndkvndakvndvkdnvdavndakndakndakdanc...
# 1  kndkcnadlkcnadkcndk;cnadkcnadkcndackdanckdancd...
# 2                       dccldlcdcldmcladmcldacmldmcc

# %%
data3 = pd.read_excel("52176ex.xlsx")

# %%
data3
# Out:
#      dwdsds     SCASC  SCSCSC  SCSACSC   SCSCSAC
# 0   DSCSCSX   SCSCASC  SCSCSC  CSACSAC     SCSAC
# 1    DSCDSC     SCASC    SCAS  SCSACSC   CASCSAC
# 2  SCASCSAC  CDASCASC       C  SSACSAC  SCSCADSC
# 3  SCASCSSC    SSCSAC  ASCSCS   SDSCSC  SCSCASCC

# %%
data2 = pd.read_csv("2176csv.csv")

# %%
data2
# Out:
#      frvfv    rferf     frefr    refrf rferfr
# 0  rfrfrfg     frfr      frfr   erfref   efrf
# 1  rfrfrfg  rfrwfrf  rfrefref  frefref    ref
# 2   rfrfrw    rrfrf  refreffr  rfrefre  refre
# 3     rfrf      frf      rfrf  rfrfref     fr

# %%
data4 = pd.read_table("https://github.com/2303a52176/AIML_2303A52176")

# %%
data4
# Out:
#                                         <!DOCTYPE html>
# 0                                                 <html
# 1                                             lang="en"
# 2       data-color-mode="auto" data-light-theme="lig...
# 3       data-a11y-animated-images="system" data-a11y...
# 4                                                     >
# ...                                                 ...
# 1934                                             </div>
# 1935      <div id="js-global-screen-reader-notice" c...
# 1936      <div id="js-global-screen-reader-notice-as...
# 1937                                            </body>
# 1938                                            </html>
#
# [1939 rows x 1 columns]
